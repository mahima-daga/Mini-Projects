# %% [markdown]
# ### Project Description
# * Topic - Loan Dataset
# * Problem statement : Loans dataset aims to identify variables which indicate if a
# person is likely to default, which can be used for identifying the risky loan
# applicants to avoid any financial loss to the company.
# * Tools/Skills used : Python and Visualizing the Data

# %% [markdown]
# ### 1. Import the dataset and understand it.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('loan.csv')
df
# Out:
#             id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0      1077501    1296599       5000         5000           4975.0
# 1      1077430    1314167       2500         2500           2500.0
# 2      1077175    1313524       2400         2400           2400.0
# 3      1076863    1277178      10000        10000          10000.0
# 4      1075358    1311748       3000         3000           3000.0
# ...        ...        ...        ...          ...              ...
# 39712    92187      92174       2500         2500           1075.0
# 39713    90665      90607       8500         8500            875.0
# 39714    90395      90390       5000         5000           1325.0
# 39715    90376      89243       5000         5000            650.0
# 39716    87023      86999       7500         7500            800.0
#
#              term int_rate  installment grade emp_length  ...  \
# 0       36 months   10.65%       162.87     B  10+ years  ...
# 1       60 months   15.27%        59.83     C   < 1 year  ...
# 2       36 months   15.96%        84.33     C  10+ years  ...
# 3       36 months   13.49%       339.31     C  10+ years  ...
# 4       60 months   12.69%        67.79     B     1 year  ...
# ...           ...      ...          ...   ...        ...  ...
# 39712   36 months    8.07%        78.42     A    4 years  ...
# 39713   36 months   10.28%       275.38     C    3 years  ...
# 39714   36 months    8.07%       156.84     A   < 1 year  ...
# 39715   36 months    7.43%       155.38     A   < 1 year  ...
# 39716   36 months   13.75%       255.43     E   < 1 year  ...
#
#                   purpose    dti   total_pymnt total_pymnt_inv  \
# 0             credit_card  27.65   5863.155187         5833.84
# 1                     car   1.00   1008.710000         1008.71
# 2          small_business   8.72   3005.666844         3005.67
# 3                   other  20.00  12231.890000        12231.89
# 4                   other  17.94   3513.330000         3513.33
# ...                   ...    ...           ...             ...
# 39712    home_improvement  11.33   2822.969293         1213.88
# 39713         credit_card   6.40   9913.491822         1020.51
# 39714  debt_consolidation   2.30   5272.161128         1397.12
# 39715               other   3.72   5174.198551          672.66
# 39716  debt_consolidation  14.29   9195.263334          980.83
#
#        total_rec_prncp  total_rec_int  last_pymnt_d  last_pymnt_amnt  \
# 0              5000.00         863.16        Jan-15           171.62
# 1               456.46         435.17        Apr-13           119.66
# 2              2400.00         605.67        Jun-14           649.91
# 3             10000.00        2214.92        Jan-15           357.48
# 4              2475.94        1037.39        May-16            67.79
# ...                ...            ...           ...              ...
# 39712          2500.00         322.97        Jul-10            80.90
# 39713          8500.00        1413.49        Jul-10           281.94
# 39714          5000.00         272.16        Apr-08             0.00
# 39715          5000.00         174.20        Jan-08             0.00
# 39716          7500.00        1695.26        Jun-10           256.59
#
#        Unnamed: 21 Unnamed: 22
# 0              NaN         NaN
# 1              NaN         NaN
# 2              NaN         NaN
# 3              NaN         NaN
# 4              NaN         NaN
# ...            ...         ...
# 39712          NaN         NaN
# 39713          NaN         NaN
# 39714          NaN         NaN
# 39715          NaN         NaN
# 39716          NaN         NaN
#
# [39717 rows x 23 columns]

# %% [markdown]
# ### 2. List down the number of rows and columns.

# %%
df.shape
# Out:
# (39717, 23)

# %% [markdown]
# ### 3. ‘Int_rate’ column is character type. With the help of lambda function convert into float type.

# %%
s=lambda x:pd.to_numeric(x)
df['int_rate']=s(df['int_rate'].str.rstrip('%'))
df['int_rate'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# ### 4. Check the datatype of each column.

# %%
df.dtypes
# Out:
# id                       int64
# member_id                int64
# loan_amnt                int64
# funded_amnt              int64
# funded_amnt_inv        float64
# term                    object
# int_rate               float64
# installment            float64
# grade                   object
# emp_length              object
# annual_inc             float64
# verification_status     object
# loan_status             object
# purpose                 object
# dti                    float64
# total_pymnt            float64
# total_pymnt_inv        float64
# total_rec_prncp        float64
# total_rec_int          float64
# last_pymnt_d            object
# last_pymnt_amnt        float64
# Unnamed: 21            float64
# Unnamed: 22            float64
# dtype: object

# %% [markdown]
# ### 5. Cleaning the dataset- Remove the columns having complete NaN value in the entire dataset.

# %%
df.dropna(axis=1,inplace=True,how='all')

# %%
df
# Out:
#             id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0      1077501    1296599       5000         5000           4975.0
# 1      1077430    1314167       2500         2500           2500.0
# 2      1077175    1313524       2400         2400           2400.0
# 3      1076863    1277178      10000        10000          10000.0
# 4      1075358    1311748       3000         3000           3000.0
# ...        ...        ...        ...          ...              ...
# 39712    92187      92174       2500         2500           1075.0
# 39713    90665      90607       8500         8500            875.0
# 39714    90395      90390       5000         5000           1325.0
# 39715    90376      89243       5000         5000            650.0
# 39716    87023      86999       7500         7500            800.0
#
#              term  int_rate  installment grade emp_length  ...  \
# 0       36 months     10.65       162.87     B  10+ years  ...
# 1       60 months     15.27        59.83     C   < 1 year  ...
# 2       36 months     15.96        84.33     C  10+ years  ...
# 3       36 months     13.49       339.31     C  10+ years  ...
# 4       60 months     12.69        67.79     B     1 year  ...
# ...           ...       ...          ...   ...        ...  ...
# 39712   36 months      8.07        78.42     A    4 years  ...
# 39713   36 months     10.28       275.38     C    3 years  ...
# 39714   36 months      8.07       156.84     A   < 1 year  ...
# 39715   36 months      7.43       155.38     A   < 1 year  ...
# 39716   36 months     13.75       255.43     E   < 1 year  ...
#
#        verification_status  loan_status             purpose    dti  \
# 0                 Verified   Fully Paid         credit_card  27.65
# 1          Source Verified  Charged Off                 car   1.00
# 2             Not Verified   Fully Paid      small_business   8.72
# 3          Source Verified   Fully Paid               other  20.00
# 4          Source Verified      Current               other  17.94
# ...                    ...          ...                 ...    ...
# 39712         Not Verified   Fully Paid    home_improvement  11.33
# 39713         Not Verified   Fully Paid         credit_card   6.40
# 39714         Not Verified   Fully Paid  debt_consolidation   2.30
# 39715         Not Verified   Fully Paid               other   3.72
# 39716         Not Verified   Fully Paid  debt_consolidation  14.29
#
#         total_pymnt  total_pymnt_inv  total_rec_prncp  total_rec_int  \
# 0       5863.155187          5833.84          5000.00         863.16
# 1       1008.710000          1008.71           456.46         435.17
# 2       3005.666844          3005.67          2400.00         605.67
# 3      12231.890000         12231.89         10000.00        2214.92
# 4       3513.330000          3513.33          2475.94        1037.39
# ...             ...              ...              ...            ...
# 39712   2822.969293          1213.88          2500.00         322.97
# 39713   9913.491822          1020.51          8500.00        1413.49
# 39714   5272.161128          1397.12          5000.00         272.16
# 39715   5174.198551           672.66          5000.00         174.20
# 39716   9195.263334           980.83          7500.00        1695.26
#
#        last_pymnt_d last_pymnt_amnt
# 0            Jan-15          171.62
# 1            Apr-13          119.66
# 2            Jun-14          649.91
# 3            Jan-15          357.48
# 4            May-16           67.79
# ...             ...             ...
# 39712        Jul-10           80.90
# 39713        Jul-10          281.94
# 39714        Apr-08            0.00
# 39715        Jan-08            0.00
# 39716        Jun-10          256.59
#
# [39717 rows x 21 columns]

# %% [markdown]
# ### 6. Write the code to find the value counts of the ‘loan_status’ category column and filter only the ‘fully paid’ and ‘charged off’ categories.

# %%
df[(df['loan_status']=='Fully Paid') | (df['loan_status']=='Charged Off')]['loan_status'].value_counts()
# Out:
# Fully Paid     32950
# Charged Off     5627
# Name: loan_status, dtype: int64

# %% [markdown]
# ### 7. Filter the ‘Emp_Len’ column to extract the numerical value from the string.

# %%
df['emp_length'].str.extract('(\d+)')
# Out:
#         0
# 0      10
# 1       1
# 2      10
# 3      10
# 4       1
# ...    ..
# 39712   4
# 39713   3
# 39714   1
# 39715   1
# 39716   1
#
# [39717 rows x 1 columns]

# %%
df['emp_length'].apply(lambda x : int(str(x).isdigit()))
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 39712    0
# 39713    0
# 39714    0
# 39715    0
# 39716    0
# Name: emp_length, Length: 39717, dtype: int64

# %% [markdown]
# ###  8. Using the Lambda function, remove the month from the ‘term’ column such that ‘36 months’, ‘60 months’ appear as 36 and 60 respectively.

# %%
df['term']=list(map(lambda x : x.replace('months',''),df['term']))
df
# Out:
#             id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  term  \
# 0      1077501    1296599       5000         5000           4975.0   36
# 1      1077430    1314167       2500         2500           2500.0   60
# 2      1077175    1313524       2400         2400           2400.0   36
# 3      1076863    1277178      10000        10000          10000.0   36
# 4      1075358    1311748       3000         3000           3000.0   60
# ...        ...        ...        ...          ...              ...   ...
# 39712    92187      92174       2500         2500           1075.0   36
# 39713    90665      90607       8500         8500            875.0   36
# 39714    90395      90390       5000         5000           1325.0   36
# 39715    90376      89243       5000         5000            650.0   36
# 39716    87023      86999       7500         7500            800.0   36
#
#        int_rate  installment grade emp_length  ...  verification_status  \
# 0         10.65       162.87     B  10+ years  ...             Verified
# 1         15.27        59.83     C   < 1 year  ...      Source Verified
# 2         15.96        84.33     C  10+ years  ...         Not Verified
# 3         13.49       339.31     C  10+ years  ...      Source Verified
# 4         12.69        67.79     B     1 year  ...      Source Verified
# ...         ...          ...   ...        ...  ...                  ...
# 39712      8.07        78.42     A    4 years  ...         Not Verified
# 39713     10.28       275.38     C    3 years  ...         Not Verified
# 39714      8.07       156.84     A   < 1 year  ...         Not Verified
# 39715      7.43       155.38     A   < 1 year  ...         Not Verified
# 39716     13.75       255.43     E   < 1 year  ...         Not Verified
#
#        loan_status             purpose    dti   total_pymnt  total_pymnt_inv  \
# 0       Fully Paid         credit_card  27.65   5863.155187          5833.84
# 1      Charged Off                 car   1.00   1008.710000          1008.71
# 2       Fully Paid      small_business   8.72   3005.666844          3005.67
# 3       Fully Paid               other  20.00  12231.890000         12231.89
# 4          Current               other  17.94   3513.330000          3513.33
# ...            ...                 ...    ...           ...              ...
# 39712   Fully Paid    home_improvement  11.33   2822.969293          1213.88
# 39713   Fully Paid         credit_card   6.40   9913.491822          1020.51
# 39714   Fully Paid  debt_consolidation   2.30   5272.161128          1397.12
# 39715   Fully Paid               other   3.72   5174.198551           672.66
# 39716   Fully Paid  debt_consolidation  14.29   9195.263334           980.83
#
#        total_rec_prncp  total_rec_int  last_pymnt_d last_pymnt_amnt
# 0              5000.00         863.16        Jan-15          171.62
# 1               456.46         435.17        Apr-13          119.66
# 2              2400.00         605.67        Jun-14          649.91
# 3             10000.00        2214.92        Jan-15          357.48
# 4              2475.94        1037.39        May-16           67.79
# ...                ...            ...           ...             ...
# 39712          2500.00         322.97        Jul-10           80.90
# 39713          8500.00        1413.49        Jul-10          281.94
# 39714          5000.00         272.16        Apr-08            0.00
# 39715          5000.00         174.20        Jan-08            0.00
# 39716          7500.00        1695.26        Jun-10          256.59
#
# [39717 rows x 21 columns]

# %% [markdown]
# #### 9. Create a new column as risky_loan_applicant by comparing loan_amnt and funded_amnt with the following criteria -If loan_amnt is less than equals to funded_amnt set it as ‘0’ else set it as ‘1’.

# %%
df['risky_loan_applicant']=list(map(lambda x,y: 0 if x<=y else 1 ,df['loan_amnt'],df['funded_amnt']))
df
# Out:
#             id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  term  \
# 0      1077501    1296599       5000         5000           4975.0   36
# 1      1077430    1314167       2500         2500           2500.0   60
# 2      1077175    1313524       2400         2400           2400.0   36
# 3      1076863    1277178      10000        10000          10000.0   36
# 4      1075358    1311748       3000         3000           3000.0   60
# ...        ...        ...        ...          ...              ...   ...
# 39712    92187      92174       2500         2500           1075.0   36
# 39713    90665      90607       8500         8500            875.0   36
# 39714    90395      90390       5000         5000           1325.0   36
# 39715    90376      89243       5000         5000            650.0   36
# 39716    87023      86999       7500         7500            800.0   36
#
#        int_rate  installment grade emp_length  ...  loan_status  \
# 0         10.65       162.87     B  10+ years  ...   Fully Paid
# 1         15.27        59.83     C   < 1 year  ...  Charged Off
# 2         15.96        84.33     C  10+ years  ...   Fully Paid
# 3         13.49       339.31     C  10+ years  ...   Fully Paid
# 4         12.69        67.79     B     1 year  ...      Current
# ...         ...          ...   ...        ...  ...          ...
# 39712      8.07        78.42     A    4 years  ...   Fully Paid
# 39713     10.28       275.38     C    3 years  ...   Fully Paid
# 39714      8.07       156.84     A   < 1 year  ...   Fully Paid
# 39715      7.43       155.38     A   < 1 year  ...   Fully Paid
# 39716     13.75       255.43     E   < 1 year  ...   Fully Paid
#
#                   purpose    dti   total_pymnt  total_pymnt_inv  \
# 0             credit_card  27.65   5863.155187          5833.84
# 1                     car   1.00   1008.710000          1008.71
# 2          small_business   8.72   3005.666844          3005.67
# 3                   other  20.00  12231.890000         12231.89
# 4                   other  17.94   3513.330000          3513.33
# ...                   ...    ...           ...              ...
# 39712    home_improvement  11.33   2822.969293          1213.88
# 39713         credit_card   6.40   9913.491822          1020.51
# 39714  debt_consolidation   2.30   5272.161128          1397.12
# 39715               other   3.72   5174.198551           672.66
# 39716  debt_consolidation  14.29   9195.263334           980.83
#
#        total_rec_prncp  total_rec_int  last_pymnt_d  last_pymnt_amnt  \
# 0              5000.00         863.16        Jan-15           171.62
# 1               456.46         435.17        Apr-13           119.66
# 2              2400.00         605.67        Jun-14           649.91
# 3             10000.00        2214.92        Jan-15           357.48
# 4              2475.94        1037.39        May-16            67.79
# ...                ...            ...           ...              ...
# 39712          2500.00         322.97        Jul-10            80.90
# 39713          8500.00        1413.49        Jul-10           281.94
# 39714          5000.00         272.16        Apr-08             0.00
# 39715          5000.00         174.20        Jan-08             0.00
# 39716          7500.00        1695.26        Jun-10           256.59
#
#       risky_loan_applicant
# 0                        0
# 1                        0
# 2                        0
# 3                        0
# 4                        0
# ...                    ...
# 39712                    0
# 39713                    0
# 39714                    0
# 39715                    0
# 39716                    0
#
# [39717 rows x 22 columns]

# %% [markdown]
# ### 10. Using the bar plot visualize the loan_status column against categoricalcolumn grade,term, verification_status . Write the observation fromeach graph.

# %%
sns.countplot(x=df['loan_status'],hue=df['grade'])
# Out:
# <AxesSubplot:xlabel='loan_status', ylabel='count'>

# %%
sns.countplot(x=df['loan_status'],hue=df['term'])
# Out:
# <AxesSubplot:xlabel='loan_status', ylabel='count'>

# %%
sns.countplot(x=df['loan_status'],hue=df['verification_status'])
# Out:
# <AxesSubplot:xlabel='loan_status', ylabel='count'>

# %% [markdown]
# #### 11.Using a user defined function convert the ‘emp_len’ column into categorical column as follows -
# #### If emp_len is less than equals to 1 then recode as ‘fresher’.
# #### If emp_len is greater than 1 and less than 3 then recode as ‘junior’.
# #### If emp_len is greater than 3 and less than 7 then recode as ‘senior’
# #### If emp_len is greater than 7 then recode as ‘expert’.

# %%
df['emp_length']=df['emp_length'].str.extract('(\d+)')
df['emp_length']=df['emp_length'].fillna(0)
df
# Out:
#             id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  term  \
# 0      1077501    1296599       5000         5000           4975.0   36
# 1      1077430    1314167       2500         2500           2500.0   60
# 2      1077175    1313524       2400         2400           2400.0   36
# 3      1076863    1277178      10000        10000          10000.0   36
# 4      1075358    1311748       3000         3000           3000.0   60
# ...        ...        ...        ...          ...              ...   ...
# 39712    92187      92174       2500         2500           1075.0   36
# 39713    90665      90607       8500         8500            875.0   36
# 39714    90395      90390       5000         5000           1325.0   36
# 39715    90376      89243       5000         5000            650.0   36
# 39716    87023      86999       7500         7500            800.0   36
#
#        int_rate  installment grade emp_length  ...  loan_status  \
# 0         10.65       162.87     B         10  ...   Fully Paid
# 1         15.27        59.83     C          1  ...  Charged Off
# 2         15.96        84.33     C         10  ...   Fully Paid
# 3         13.49       339.31     C         10  ...   Fully Paid
# 4         12.69        67.79     B          1  ...      Current
# ...         ...          ...   ...        ...  ...          ...
# 39712      8.07        78.42     A          4  ...   Fully Paid
# 39713     10.28       275.38     C          3  ...   Fully Paid
# 39714      8.07       156.84     A          1  ...   Fully Paid
# 39715      7.43       155.38     A          1  ...   Fully Paid
# 39716     13.75       255.43     E          1  ...   Fully Paid
#
#                   purpose    dti   total_pymnt  total_pymnt_inv  \
# 0             credit_card  27.65   5863.155187          5833.84
# 1                     car   1.00   1008.710000          1008.71
# 2          small_business   8.72   3005.666844          3005.67
# 3                   other  20.00  12231.890000         12231.89
# 4                   other  17.94   3513.330000          3513.33
# ...                   ...    ...           ...              ...
# 39712    home_improvement  11.33   2822.969293          1213.88
# 39713         credit_card   6.40   9913.491822          1020.51
# 39714  debt_consolidation   2.30   5272.161128          1397.12
# 39715               other   3.72   5174.198551           672.66
# 39716  debt_consolidation  14.29   9195.263334           980.83
#
#        total_rec_prncp  total_rec_int  last_pymnt_d  last_pymnt_amnt  \
# 0              5000.00         863.16        Jan-15           171.62
# 1               456.46         435.17        Apr-13           119.66
# 2              2400.00         605.67        Jun-14           649.91
# 3             10000.00        2214.92        Jan-15           357.48
# 4              2475.94        1037.39        May-16            67.79
# ...                ...            ...           ...              ...
# 39712          2500.00         322.97        Jul-10            80.90
# 39713          8500.00        1413.49        Jul-10           281.94
# 39714          5000.00         272.16        Apr-08             0.00
# 39715          5000.00         174.20        Jan-08             0.00
# 39716          7500.00        1695.26        Jun-10           256.59
#
#       risky_loan_applicant
# 0                        0
# 1                        0
# 2                        0
# 3                        0
# 4                        0
# ...                    ...
# 39712                    0
# 39713                    0
# 39714                    0
# 39715                    0
# 39716                    0
#
# [39717 rows x 22 columns]

# %%
def convert(x):
        if float(x)<=1:
            return 'fresher'
        elif 1<float(x)<=3:
            return 'junior'
        elif 3<float(x)<=7:
            return 'senior'
        else :
            return 'expert'
df['emp_length'] =df['emp_length'].apply(convert)
df
# Out:
#             id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  term  \
# 0      1077501    1296599       5000         5000           4975.0   36
# 1      1077430    1314167       2500         2500           2500.0   60
# 2      1077175    1313524       2400         2400           2400.0   36
# 3      1076863    1277178      10000        10000          10000.0   36
# 4      1075358    1311748       3000         3000           3000.0   60
# ...        ...        ...        ...          ...              ...   ...
# 39712    92187      92174       2500         2500           1075.0   36
# 39713    90665      90607       8500         8500            875.0   36
# 39714    90395      90390       5000         5000           1325.0   36
# 39715    90376      89243       5000         5000            650.0   36
# 39716    87023      86999       7500         7500            800.0   36
#
#        int_rate  installment grade emp_length  ...  loan_status  \
# 0         10.65       162.87     B     expert  ...   Fully Paid
# 1         15.27        59.83     C    fresher  ...  Charged Off
# 2         15.96        84.33     C     expert  ...   Fully Paid
# 3         13.49       339.31     C     expert  ...   Fully Paid
# 4         12.69        67.79     B    fresher  ...      Current
# ...         ...          ...   ...        ...  ...          ...
# 39712      8.07        78.42     A     senior  ...   Fully Paid
# 39713     10.28       275.38     C     junior  ...   Fully Paid
# 39714      8.07       156.84     A    fresher  ...   Fully Paid
# 39715      7.43       155.38     A    fresher  ...   Fully Paid
# 39716     13.75       255.43     E    fresher  ...   Fully Paid
#
#                   purpose    dti   total_pymnt  total_pymnt_inv  \
# 0             credit_card  27.65   5863.155187          5833.84
# 1                     car   1.00   1008.710000          1008.71
# 2          small_business   8.72   3005.666844          3005.67
# 3                   other  20.00  12231.890000         12231.89
# 4                   other  17.94   3513.330000          3513.33
# ...                   ...    ...           ...              ...
# 39712    home_improvement  11.33   2822.969293          1213.88
# 39713         credit_card   6.40   9913.491822          1020.51
# 39714  debt_consolidation   2.30   5272.161128          1397.12
# 39715               other   3.72   5174.198551           672.66
# 39716  debt_consolidation  14.29   9195.263334           980.83
#
#        total_rec_prncp  total_rec_int  last_pymnt_d  last_pymnt_amnt  \
# 0              5000.00         863.16        Jan-15           171.62
# 1               456.46         435.17        Apr-13           119.66
# 2              2400.00         605.67        Jun-14           649.91
# 3             10000.00        2214.92        Jan-15           357.48
# 4              2475.94        1037.39        May-16            67.79
# ...                ...            ...           ...              ...
# 39712          2500.00         322.97        Jul-10            80.90
# 39713          8500.00        1413.49        Jul-10           281.94
# 39714          5000.00         272.16        Apr-08             0.00
# 39715          5000.00         174.20        Jan-08             0.00
# 39716          7500.00        1695.26        Jun-10           256.59
#
#       risky_loan_applicant
# 0                        0
# 1                        0
# 2                        0
# 3                        0
# 4                        0
# ...                    ...
# 39712                    0
# 39713                    0
# 39714                    0
# 39715                    0
# 39716                    0
#
# [39717 rows x 22 columns]

# %% [markdown]
# ### 12.Find the sum of ‘loan_amnt’ for each grade and display the distribution of ‘loan_amnt’ using a pie plot.

# %%
loans=df.groupby('grade')['loan_amnt'].sum()
loans
# Out:
# grade
# A     86982400
# B    133651350
# C     89115825
# D     65160400
# E     45037900
# F     19263100
# G      6391675
# Name: loan_amnt, dtype: int64

# %%
plt.figure(figsize=(10,8))
plt.pie(data=loans,x=loans.values,labels=loans.index,autopct='%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x207f610d520>,
#   <matplotlib.patches.Wedge at 0x207f610dc70>,
#   <matplotlib.patches.Wedge at 0x207f63d73d0>,
#   <matplotlib.patches.Wedge at 0x207f63d7af0>,
#   <matplotlib.patches.Wedge at 0x207f63e0250>,
#   <matplotlib.patches.Wedge at 0x207f63e0970>,
#   <matplotlib.patches.Wedge at 0x207f63e70d0>],
#  [Text(0.8995636661270169, 0.6330759911607144, 'A'),
#   Text(-0.6192556904355261, 0.9091327680065328, 'B'),
#   Text(-0.9092817764440416, -0.619036873721403, 'C'),
#   Text(0.12579028263560507, -1.0927839698652497, 'D'),
#   Text(0.8558350158159784, -0.6910473396976969, 'E'),
#   Text(1.0720438612621985, -0.24641826135665468, 'F'),
#   Text(1.0988833533907465, -0.04955174710046001, 'G')],
#  [Text(0.4906710906147364, 0.34531417699675326, '19.5%'),
#   Text(-0.33777583114665055, 0.495890600730836, '30.0%'),
#   Text(-0.49597187806038623, -0.33765647657531067, '20.0%'),
#   Text(0.06861288143760276, -0.5960639835628634, '14.6%'),
#   Text(0.46681909953598816, -0.37693491256238015, '10.1%'),
#   Text(0.5847511970521082, -0.13440996073999345, '4.3%'),
#   Text(0.5993909200313162, -0.02702822569116, '1.4%')])
